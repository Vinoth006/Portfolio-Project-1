# %%
import re
users = {}
status = ""
def displaymenu():
  status = input("Welcome: Are you registered user ? yes/no press q to quit")
  if status == "yes":
     oldUser()

  elif status == "no":
    newuser()
def newuser ():
  createlogin = input("Create login name: ")
   
  if ("@"and"." in createlogin):
    if(regex.search(createlogin[0]) == None):
      if createlogin in users:
        print("\n Login name already exist!\n")
      else:
        createpassword = input("Create Password: ")
        if (5<len(createpassword)) and (len(createpassword)<16):
         users[createlogin] = createpassword
         print("\nUser created\n")
        else:
          print("Your password length is not in needed length.")
  else:
      print("Invalid id kindly check again")
  #else:
    #print("Your User id start with out Number")
def oldUser ():
    login = input("Enter login name: ")
    password = input("Enter your Password")

    if login in users and users[login] == password:
      print("\nLogin successful\n")
    else:
      print("\nUser doen't exist or wrong password!\n")


while status != "q":
  displaymenu()
